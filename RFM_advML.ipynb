# %%
# !pip install xlrd
# Out:
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...

# %%
import pandas as pd 
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"C:\Users\ASHISH PAL\Downloads\Sample - Superstore (1).xls")

# %%
df
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2019-103800 2019-01-03 2019-01-07  Standard Class
# 1           2  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 2           3  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 3           4  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 4           5  US-2019-141817 2019-01-05 2019-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10190   10191  US-2022-115427 2022-12-30 2023-01-03  Standard Class
# 10191   10192  US-2022-156720 2022-12-30 2023-01-03  Standard Class
# 10192   10193  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10193   10194  CA-2022-143500 2022-12-30 2023-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %%
df.shape
# Out:
# (10194, 21)

# %%
df.describe()
# Out:
#              Row ID                     Order Date  \
# count  10194.000000                          10194
# mean    5097.500000  2021-04-29 11:48:25.002942976
# min        1.000000            2019-01-03 00:00:00
# 25%     2549.250000            2020-05-14 00:00:00
# 50%     5097.500000            2021-06-25 00:00:00
# 75%     7645.750000            2022-05-14 00:00:00
# max    10194.000000            2022-12-30 00:00:00
# std     2942.898656                            NaN
#
#                            Ship Date         Sales      Quantity  \
# count                          10194  10194.000000  10194.000000
# mean   2021-05-03 10:52:45.626839296    228.225854      3.791838
# min              2019-01-07 00:00:00      0.444000      1.000000
# 25%              2020-05-19 00:00:00     17.220000      2.000000
# 50%              2021-06-28 00:00:00     53.910000      3.000000
# 75%              2022-05-18 00:00:00    209.500000      5.000000
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df['Order Date'].min(),df['Order Date'].max()
# Out:
# (Timestamp('2019-01-03 00:00:00'), Timestamp('2022-12-30 00:00:00'))

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_recency=df.groupby(by='Customer Name',
                     as_index=False)['Order Date'].max()

df_recency.columns=['Customer Name','LastPurchaseDate']

recent_date=df_recency['LastPurchaseDate'].max()

df_recency['Recency']=df_recency['LastPurchaseDate'].apply(lambda x:(recent_date- x).days)
df_recency.head()
# Out:
#      Customer Name LastPurchaseDate  Recency
# 0    Aaron Bergman       2021-11-10      415
# 1    Aaron Hawkins       2022-12-18       12
# 2   Aaron Smayling       2022-10-03       88
# 3  Adam Bellavance       2022-11-06       54
# 4        Adam Hart       2022-11-26       34

# %%
df_recency.Recency.min()
# Out:
# 0

# %%
df_recency.max()
# Out:
# Customer Name        Zuschuss Donatelli
# LastPurchaseDate    2022-12-30 00:00:00
# Recency                            1165
# dtype: object

# %%
frequency_df=df.drop_duplicates().groupby(
    by=['Customer Name'], as_index=False)['Order Date'].count()

frequency_df.columns=['Customer Name','Frequency']
frequency_df.head()
# Out:
#      Customer Name  Frequency
# 0    Aaron Bergman          6
# 1    Aaron Hawkins         11
# 2   Aaron Smayling         10
# 3  Adam Bellavance         18
# 4        Adam Hart         20

# %%
frequency_df.max()
# Out:
# Customer Name    Zuschuss Donatelli
# Frequency                        41
# dtype: object

# %%
df['Total']=df['Sales']*df['Quantity']
monetary_df=df.groupby(by='Customer Name',as_index=False)['Total'].sum()
monetary_df.columns=['Customer Name','Monetary']
monetary_df.max()
# Out:
# Customer Name    Zuschuss Donatelli
# Monetary                  146749.77
# dtype: object

# %%
rf_df=df_recency.merge(frequency_df,on='Customer Name')
rfm_df=rf_df.merge(monetary_df,on='Customer Name').drop(columns='LastPurchaseDate')
rfm_df
# Out:
#           Customer Name  Recency  Frequency   Monetary
# 0         Aaron Bergman      415          6   1984.480
# 1         Aaron Hawkins       12         11  11459.552
# 2        Aaron Smayling       88         10   9088.880
# 3       Adam Bellavance       54         18  35390.580
# 4             Adam Hart       34         20   9664.265
# ..                  ...      ...        ...        ...
# 795        Xylona Preis       43         34   9183.576
# 796       Yana Sorensen        9         12  46478.992
# 797      Yoseph Carroll        4          8  27208.926
# 798    Zuschuss Carroll       54         31  40212.889
# 799  Zuschuss Donatelli      202          9   6492.448
#
# [800 rows x 4 columns]

# %%
rfm_df[(rfm_df.Monetary==rfm_df.Monetary.max())]
# Out:
#     Customer Name  Recency  Frequency   Monetary
# 693   Sean Miller       79         15  146749.77

# %%
rfm_df.describe()
# Out:
#            Recency   Frequency       Monetary
# count   800.000000  800.000000     800.000000
# mean    145.301250   12.742500   14520.160452
# std     185.738698    6.531234   15503.935013
# min       0.000000    1.000000      10.449000
# 25%      29.000000    8.000000    4609.445000
# 50%      74.000000   12.000000   10007.561000
# 75%     178.500000   16.000000   18777.998000
# max    1165.000000   41.000000  146749.770000

# %%
rfm_df['R_rank']=rfm_df['Recency'].rank(ascending=False)
rfm_df['F_rank']=rfm_df['Frequency'].rank(ascending=True)
rfm_df['M_rank']=rfm_df['Monetary'].rank(ascending=True)

#normalizing the rank of the customers
rfm_df['R_rank_norm']=(rfm_df['R_rank']/rfm_df['R_rank'].max())*100
rfm_df['F_rank_norm']=(rfm_df['F_rank']/rfm_df['F_rank'].max())*100
rfm_df['M_rank_norm']=(rfm_df['M_rank']/rfm_df['M_rank'].max())*100

rfm_df.drop(columns=['R_rank','F_rank','M_rank'],inplace=True)
rfm_df
# Out:
#           Customer Name  Recency  Frequency   Monetary  R_rank_norm  \
# 0         Aaron Bergman      415          6   1984.480     8.959900
# 1         Aaron Hawkins       12         11  11459.552    90.162907
# 2        Aaron Smayling       88         10   9088.880    45.676692
# 3       Adam Bellavance       54         18  35390.580    58.959900
# 4             Adam Hart       34         20   9664.265    72.305764
# ..                  ...      ...        ...        ...          ...
# 795        Xylona Preis       43         34   9183.576    64.786967
# 796       Yana Sorensen        9         12  46478.992    91.791980
# 797      Yoseph Carroll        4          8  27208.926    97.055138
# 798    Zuschuss Carroll       54         31  40212.889    58.959900
# 799  Zuschuss Donatelli      202          9   6492.448    22.055138
#
#      F_rank_norm  M_rank_norm
# 0        12.9375       10.875
# 1        45.3125       55.875
# 2        38.1250       46.125
# ...

# %%
rfm_df['RFM_Score']=0.15*rfm_df['R_rank_norm']+\
                     0.28 * rfm_df['R_rank_norm']+0.57*rfm_df['M_rank_norm']

rfm_df['RFM_Score'] *=0.05
rfm_df=rfm_df.round(2)
rfm_df.RFM_Score.min()
rfm_df[['Customer Name',"RFM_Score"]].max()
rfm_df.loc[(rfm_df.RFM_Score ==rfm_df.RFM_Score.max()),['Customer Name','RFM_Score']]
# Out:
#        Customer Name  RFM_Score
# 595  Patrick O'Brill        4.9

# %%
rfm_df['RFM_Score'].describe()
# Out:
# count    800.000000
# mean       2.505900
# std        1.121202
# min        0.050000
# 25%        1.607500
# 50%        2.570000
# 75%        3.382500
# max        4.900000
# Name: RFM_Score, dtype: float64

# %%
rfm_df['Customer_Segment'] = np.where(
    rfm_df['RFM_Score'] > 4.5, 'Top Customers',
    np.where(rfm_df['RFM_Score'] > 4, 'High Value Customers',
    np.where(rfm_df['RFM_Score'] > 3, 'Medium Value Customers',
    np.where(rfm_df['RFM_Score'] > 1.5, 'Low Value Customers', 'Lost Customers')))
)

# Display only the 'Customer_Segment' column
rfm_df
# Out:
#           Customer Name  Recency  Frequency  Monetary  R_rank_norm  \
# 0         Aaron Bergman      415          6   1984.48         8.96
# 1         Aaron Hawkins       12         11  11459.55        90.16
# 2        Aaron Smayling       88         10   9088.88        45.68
# 3       Adam Bellavance       54         18  35390.58        58.96
# 4             Adam Hart       34         20   9664.26        72.31
# ..                  ...      ...        ...       ...          ...
# 795        Xylona Preis       43         34   9183.58        64.79
# 796       Yana Sorensen        9         12  46478.99        91.79
# 797      Yoseph Carroll        4          8  27208.93        97.06
# 798    Zuschuss Carroll       54         31  40212.89        58.96
# 799  Zuschuss Donatelli      202          9   6492.45        22.06
#
#      F_rank_norm  M_rank_norm  RFM_Score        Customer_Segment
# 0          12.94        10.88       0.50          Lost Customers
# ...

# %%
segment_counts = rfm_df['Customer_Segment'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(segment_counts, 
        labels=segment_counts.index, 
        autopct='%1.1f%%', 
        startangle=140, 
        colors=plt.cm.Paired.colors)

# Add a title
plt.title('Customer Segment Distribution')
plt.show()
